# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os,sys
from matplotlib import animation

# %matplotlib notebook
plt.style.use('dark_background')
color = ['#8dd3c7','#feffb3','#bfbbd9','#fa8174','#81b1d2','#fdb462','#b3de69','#bc82bd','#ccebc4','#ffed6f']

# %%
files = os.listdir()
files = [f for f in files if ".ipy" not in f]

# %%
pd.read_csv(files[0],skiprows = 2,sep="\s+", header = None,usecols = [0,1])
# Out:
#             0   1
# 0      0.0250   9
# 1      0.0252   9
# 2      0.0254  12
# 3      0.0256  12
# 4      0.0258  14
# ...       ...  ..
# 10235  1.9990   0
# 10236  1.9992   0
# 10237  1.9994   0
# 10238  1.9996   1
# 10239  1.9998   1
#
# [10240 rows x 2 columns]

# %%
file
# Out:
# 'final_aved_Data3min.csv'

# %%
i = files[0]
data = pd.read_csv(i,skiprows = 2,sep="\s+", header = None,usecols = [0,1])
ave_data = pd.DataFrame()
ave_data['Freq'] = data[0]
i = 0

for ii in range(int(len(files[:-2])/3)):
#     sep = int(len(files[:-2])/3)
    val = np.empty(10240)
    val.fill(0)
    for file in files[i:i+3]:
        if 'ave' not in file:
            data1 = pd.read_csv(file,skiprows = 2,sep="\s+", header = None,usecols = [0,1])
            val += np.array(data1[1].values)
#         print(i)
    vall = pd.Series(val)
    ave_data[i]=vall
    i+=3

# %%
ave_data
# Out:
#          Freq     0     3     6     9    12    15    18    21    24  ...  \
# 0      0.0250  11.0  22.0  26.0   8.0  18.0  12.0  19.0  29.0  28.0  ...
# 1      0.0252  10.0  11.0  31.0  14.0  11.0  19.0  21.0  23.0  21.0  ...
# 2      0.0254  14.0  18.0  27.0  11.0   7.0   9.0  16.0  18.0  25.0  ...
# 3      0.0256  15.0   6.0  21.0  11.0  12.0  12.0  12.0  16.0  24.0  ...
# 4      0.0258  18.0  11.0  27.0  10.0   9.0  14.0  12.0  15.0  31.0  ...
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 10235  1.9990   1.0   0.0   1.0   3.0   0.0   0.0   2.0   1.0   4.0  ...
# 10236  1.9992   4.0   2.0   3.0   2.0   1.0   3.0   5.0   4.0   2.0  ...
# 10237  1.9994   0.0   3.0   2.0   2.0   0.0   1.0   3.0   3.0   1.0  ...
# 10238  1.9996   1.0   4.0   3.0   1.0   4.0   0.0   4.0   1.0   0.0  ...
# 10239  1.9998   5.0   4.0   3.0   2.0   1.0   2.0   3.0   3.0   2.0  ...
#
#        3996  3999  4002  4005  4008  4011  4014  4017  4020  4023
# ...

# %%
aved_data = pd.DataFrame([])
aved_data['freq'] = ave_data['Freq']
aved_data['values'] = values
aved_data['std'] = np.array(std)/np.sqrt(4026)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1b4427c39d31> in <module>
#       1 aved_data = pd.DataFrame([])
#       2 aved_data['freq'] = ave_data['Freq']
# ----> 3 aved_data['values'] = values
#       4 aved_data['std'] = np.array(std)/np.sqrt(4026)
#
# NameError: name 'values' is not defined

# %%
# aved_data.to_csv('final_aved_Data3min.csv')

# %%
datt = ave_data.drop(np.arange(4020,4028,1), axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-26dd1c991e2e> in <module>
# ----> 1 datt = ave_data.drop(np.arange(4020,4028,1), axis = 1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4310             level=level,
#    4311             inplace=inplace,
# -> 4312             errors=errors,
#    4313         )
#    4314
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ...

# %%
values = []
std = []
for i in range(len(ave_data)):
    dat = ave_data.iloc[i]
    values += [np.mean(dat.values[1:])]
    std += [np.std(dat.values[1:])]

# %%
stdd = np.array(std)/np.sqrt(4026)

# %%
ave_data[3]
# Out:
# 0        22.0
# 1        11.0
# 2        18.0
# 3         6.0
# 4        11.0
#          ...
# 10235     0.0
# 10236     2.0
# 10237     3.0
# 10238     4.0
# 10239     4.0
# Name: 3, Length: 10240, dtype: float64

# %%
np.arange(0,100,3)
# Out:
# array([ 0,  3,  6,  9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48,
#        51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99])

# %%
fig, ax = plt.subplots(figsize = (16,8))

for i in np.arange(0,1000,3):
    ax.plot(aved_data['freq'],ave_data[i],linewidth = 0.5,color = color[0],alpha = 1,label = 'Raw Data')
    
i = i+3
ax.plot(aved_data['freq'],ave_data[i],linewidth = 0.5,color = color[0],alpha = 1,label = 'Raw Data')
ax.plot(aved_data['freq'],values, linewidth = 2,color = color[1],label = 'Averaged Data',zorder = 101)
ax.fill_between(ave_data['Freq'], values-stdd, values+stdd,color = 'b',alpha = 1,label = 'Error Bar',zorder = 100)

ax.set_ylabel('Counts',fontsize = 15)
# ax.legend()

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(),fontsize = 15)

# for lh in handles: 
#     lh.set_alpha(1)

plt.show()
# plt.errorbar(ave_data['Freq'],values,std)

# %%
ave_data = pd.DataFrame([])

# %%
ave_data['freq'] = dataa[0]
ave_data['vals'] = dataa['averaged']*3

# %%
len(files[:-2])
# Out:
# 4026

# %%
ave_data.to_csv('averaged_data3min.csv')

# %%
#Animate over the all the 

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2,20))
line, = ax.plot([], [], lw=0.1)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    data = pd.read_csv(files[i],skiprows = 2,sep="\s+", header = None,usecols = [0,1])
    x = data[0].values
    y = data[1].values
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=len(files), interval=20,blit=False)

# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is used, so that
# the video can be embedded in html5.  You may need to adjust this for
# your system: for more information, see
# http://matplotlib.sourceforge.net/api/animation_api.html
# anim.save('basic_animation.mp4', fps=30, extra_args=['-vcodec', 'libx264'])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
