# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
from scipy import optimize

# %%
path = '/Users/wendy/Desktop/111/GMA/111B_Lab_Voltage_variation.csv'

# %%
try: 
    from openpyxl.cell import get_column_letter
except ImportError:
    from openpyxl.utils import get_column_letter

# %%
pd.read_csv(path)
# Out:
#    Block_material  Thickness_claim  Block_thickness(mm)  Err(mm)  \
# 0              Pb            1.058                0.925    0.005
# 1              Pb            0.430                0.855    0.005
# 2              Pb            6.580                6.159    0.005
# 3              Pb            5.365                5.253    0.005
# 4              Pb            0.520                0.930    0.005
# 5              Pb            0.570                1.465    0.005
# 6              Cu           15.250               15.260    0.005
# 7              Cu            6.330                6.396    0.005
# 8              Cu            2.140                2.170    0.005
# 9              Cu            0.751                0.780    0.005
# 10             Cu            0.752                0.780    0.005
# 11             Al           25.430               25.465    0.005
# 12             Al           15.010               14.995    0.005
# 13             Al            9.715                9.815    0.005
# 14             Al            6.420                6.481    0.005
# 15             Al            1.050                1.049    0.005
# 16             Al            0.800                0.828    0.005
#
#     Peak_height Cs(Run2) Folder_name Cs  Peak_height Na(Run2) Folder_name Na
# 0                    450     4-24-46 PM                   499    12-44-20 PM
# 1                    450     4-38-10 PM                   485     1-01-36 PM
# 2                    230     4-46-18 PM                   224    12-51-33 PM
# 3                    230     4-53-09 PM                   204    12-55-15 PM
# 4                    400     5-00-39 PM                   460    12-47-44 PM
# 5                    400     5-04-09 PM                   458     1-07-03 PM
# 6                    170     3-02-11 PM                   213     1-13-06 PM
# 7                    289     2-57-51 PM                   377     1-17-06 PM
# 8                    361     2-53-43 PM                   492     1-22-36 PM
# 9                    443     2-49-02 PM                   536     1-26-11 PM
# 10                   403     2-39-27 PM                   505     1-29-42 PM
# 11                   274     2-18-34 PM                   344     1-33-41 PM
# 12                   341     2-14-57 PM                   404     1-37-19 PM
# 13                   362     2-10-25 PM                   454     1-41-02 PM
# 14                   381     2-06-49 PM                   525     1-45-01 PM
# 15                   420     2-02-29 PM                   558     1-48-47 PM
# 16                   421     1-58-46 PM                   573     1-52-47 PM
